# %% [markdown]
# ## 네이버 지도

# %%
import os
import sys
import urllib.request

client_id = "idnumber"
client_secret = "secretcode"
encText = urllib.parse.quote("불정로 6")
url = "https://naveropenapi.apigw.ntruss.com/map-geocode/v2/geocode?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/map/geocode.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-NCP-APIGW-API-KEY-ID",client_id)
request.add_header("X-NCP-APIGW-API-KEY",client_secret)

# type(request)
response = urllib.request.urlopen(request)

rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {"status":"OK","meta":{"totalCount":1,"page":1,"count":1},"addresses":[{"roadAddress":"경기도 성남시 분당구 불정로 6 NAVER그린팩토리","jibunAddress":"경기도 성남시 분당구 정자동 178-1 NAVER그린팩토리","englishAddress":"6, Buljeong-ro, Bundang-gu, Seongnam-si, Gyeonggi-do, Republic of Korea","addressElements":[{"types":["SIDO"],"longName":"경기도","shortName":"경기도","code":""},{"types":["SIGUGUN"],"longName":"성남시 분당구","shortName":"성남시 분당구","code":""},{"types":["DONGMYUN"],"longName":"정자동","shortName":"정자동","code":""},{"types":["RI"],"longName":"","shortName":"","code":""},{"types":["ROAD_NAME"],"longName":"불정로","shortName":"불정로","code":""},{"types":["BUILDING_NUMBER"],"longName":"6","shortName":"6","code":""},{"types":["BUILDING_NAME"],"longName":"NAVER그린팩토리","shortName":"NAVER그린팩토리","code":""},{"types":["LAND_NUMBER"],"longName":"178-1","shortName":"178-1","code":""},{"types":["POSTAL_CODE"],"longName":"13561","shortName":"13561","code":""}],"x":"127.1054065","y":"37.3595669","distance":0.0}],"errorMessage":""}

# %% [markdown]
# ## 카카오 지도
# 앱 개발자 등록: https://developers.kakao.com/
#
# API 지도 : https://developers.kakao.com/docs/restapi/local#%EC%B9%B4%ED%85%8C%EA%B3%A0%EB%A6%AC-%EA%B2%80%EC%83%89
#
# 엑세스 토큰 발급: https://developers.kakao.com/docs/restapi/tool

# %%
import requests 
import os
import json

# %%
api_url = 'https://dapi.kakao.com'
api_root = api_url + '/v2/local/search/category.json?category_group_code='
cat_code = 'CS2' #편의점
header_info = {"Authorization" : "KakaoAK d42f3703011e33a96a2875bb71a2f329"}

# %%
url = api_root + cat_code
headers = header_info

# %%
rst = requests.get(url, headers=headers)

# %%
rst.text
# Out:
# '{"documents":[{"address_name":"서울 송파구 잠실동 183-1","category_group_code":"CS2","category_group_name":"편의점","category_name":"가정,생활 \\u003e 슈퍼마켓 \\u003e 편의점","distance":"","id":"21324964","phone":"02-418-8605","place_name":"원스탑편의점","place_url":"http://place.map.kakao.com/21324964","road_address_name":"서울 송파구 백제고분로7길 39","x":"127.08308774413","y":"37.5109330972288"},{"address_name":"서울 마포구 마포동 418-1","category_group_code":"CS2","category_group_name":"편의점","category_name":"가정,생활 \\u003e 슈퍼마켓 \\u003e 편의점","distance":"","id":"19264430","phone":"070-4414-8253","place_name":"마포타워편의점","place_url":"http://place.map.kakao.com/19264430","road_address_name":"서울 마포구 마포대로4다길 41","x":"126.944003443909","y":"37.535128349661"},{"address_name":"서울 서초구 반포동 1333-1","category_group_code":"CS2","category_group_name":"편의점","category_name":"가정,생활 \\u003e 슈퍼마켓 \\u003e 편의점 \\u003e 이마트24","distance":"","id":"1699666933","phone":"02-6916-1500","place_name":"이마트24 R동작대교구름점","place_url":"http://place.map.kakao.com/
# ...

# %%
rst.json()
# Out:
# {'documents': [{'address_name': '서울 송파구 잠실동 183-1',
#    'category_group_code': 'CS2',
#    'category_group_name': '편의점',
#    'category_name': '가정,생활 > 슈퍼마켓 > 편의점',
#    'distance': '',
#    'id': '21324964',
#    'phone': '02-418-8605',
#    'place_name': '원스탑편의점',
#    'place_url': 'http://place.map.kakao.com/21324964',
#    'road_address_name': '서울 송파구 백제고분로7길 39',
#    'x': '127.08308774413',
#    'y': '37.5109330972288'},
#   {'address_name': '서울 마포구 마포동 418-1',
#    'category_group_code': 'CS2',
#    'category_group_name': '편의점',
#    'category_name': '가정,생활 > 슈퍼마켓 > 편의점',
#    'distance': '',
#    'id': '19264430',
#    'phone': '070-4414-8253',
#    'place_name': '마포타워편의점',
#    'place_url': 'http://place.map.kakao.com/19264430',
#    'road_address_name': '서울 마포구 마포대로4다길 41',
#    'x': '126.944003443909',
#    'y': '37.535128349661'},
#   {'address_name': '서울 서초구 반포동 1333-1',
#    'category_group_code': 'CS2',
#    'category_group_name': '편의점',
# ...

# %% [markdown]
# ### (미완성) 한 번에 45개씩만 보여줘서, 모든 45342개 print + json 포맷으로 저장하는 방법

# %%
i = 1
url = api_root + cat_code+"&page=" + str(i)
#print(url)
rst = requests.get(url, headers = headers)
#rst.text
rst.json()

# %%
  def _write_data(self, data) :
        with open('stores.json', 'w') as file:
            file.write(data)
            if D_DEBUG :
                print("===================")
                print("————text———")
                data_dic = json.loads(data)
                print(data_dic['text'])
                print("————json———")
                print(data)
            return True

# %%
rst.json()
# Out:
# {'documents': [{'address_name': '서울 강남구 논현동 263',
#    'category_group_code': 'CS2',
#    'category_group_name': '편의점',
#    'category_name': '가정,생활 > 슈퍼마켓 > 편의점 > CU',
#    'distance': '',
#    'id': '1954960093',
#    'phone': '',
#    'place_name': 'CU 논현두산위브점',
#    'place_url': 'http://place.map.kakao.com/1954960093',
#    'road_address_name': '서울 강남구 언주로122길 28',
#    'x': '127.038017735415',
#    'y': '37.5119364943492'},
#   {'address_name': '서울 송파구 문정동 61-7',
#    'category_group_code': 'CS2',
#    'category_group_name': '편의점',
#    'category_name': '가정,생활 > 슈퍼마켓 > 편의점 > GS25',
#    'distance': '',
#    'id': '12296944',
#    'phone': '02-449-4575',
#    'place_name': 'GS25 문정중앙점',
#    'place_url': 'http://place.map.kakao.com/12296944',
#    'road_address_name': '서울 송파구 문정로4길 10-30',
#    'x': '127.124618718369',
#    'y': '37.4854882178611'},
#   {'address_name': '서울 송파구 풍납동 479',
#    'category_group_code': 'CS2',
#    'category_group_name': '편의점',
# ...
